# %% [markdown]
# <a href="https://colab.research.google.com/github/varun04044/Expense_Tracking/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
df = pd.read_csv("mall-customers-data.csv")

display(df.head())
display(df.corr(numeric_only=True))
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40
#                 customer_id       age  annual_income  spending_score
# customer_id        1.000000 -0.026763       0.977548        0.013835
# age               -0.026763  1.000000      -0.012398       -0.327227
# annual_income      0.977548 -0.012398       1.000000        0.009903
# spending_score     0.013835 -0.327227       0.009903        1.000000

# %%
sns.set(style="whitegrid")
sns.displot(df["annual_income"], kde=True, color="dodgerblue")

plt.title("Distribution of annual income (in k$)")
plt.xlabel("Range of annual income (in k$)")
plt.ylabel("Count")

plt.show()

# %%
sns.set(style="whitegrid")
sns.displot(df["age"], kde=True, color="dodgerblue")

plt.title('Distribution of age', fontsize = 20)
plt.xlabel('Range of age')
plt.ylabel('Count')

plt.show()

# %%
sns.set(style="whitegrid")
sns.displot(df["spending_score"], kde=True, color="dodgerblue")

plt.title('Distribution of spending score', fontsize = 20)
plt.xlabel('Range of spending score (1-100)')
plt.ylabel('Count')

plt.show()

# %%
genders = df["gender"].value_counts()

colors = {
    "Male": "dodgerblue",
    "Female": "orange"
}

sns.set(style="whitegrid")
sns.barplot(x=genders.index, y=genders.values, palette=colors)

plt.show()
# Out:
# <ipython-input-10-0105e36918a6>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=genders.index, y=genders.values, palette=colors)

# %%
X = df[["annual_income", "spending_score"]]
X.head()
# Out:
#    annual_income  spending_score
# 0             15              39
# 1             15              81
# 2             16               6
# 3             16              77
# 4             17              40

# %%
sns.scatterplot(x="annual_income", y="spending_score", data=X, s=60, color="dodgerblue")

plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Spending Score (1-100) vs Annual Income (k$)')

plt.show()

# %%
wcss = []
for i in range(1, 11):
    k_means = KMeans(n_clusters=i, n_init="auto")
    k_means.fit(X)
    wcss.append(k_means.inertia_)

# the elbow curve
plt.plot(range(1, 11), wcss)
plt.plot(range(1, 11), wcss, linewidth=2.5, color="red", marker="8")

plt.title("Elbow Curve")
plt.xlabel("Number of clusters (values of k)")
plt.ylabel("WCSS values")
plt.xticks(np.arange(1, 11, 1))

plt.show()

# %%
# taking k = 5
k_means_1 = KMeans(n_clusters=3, n_init="auto")

# fitting the input data
k_means_1.fit(X)

# predicting the labels of the input data
y_pred = k_means_1.predict(X)

# adding the labels to a column named label
df["label"] = y_pred

df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score  label
# 0            1    Male   19             15              39      0
# 1            2    Male   21             15              81      0
# 2            3  Female   20             16               6      0
# 3            4  Female   23             16              77      0
# 4            5  Female   31             17              40      0

# %%
colors = ["red", "green", "dodgerblue", "gold", "purple"]

# scatterplot of the clusters
sns.scatterplot(
    x="annual_income",
    y="spending_score",
    hue="label",
    palette=colors,
    legend="full",
    data=df,
    s=60
)

plt.xlabel('Annual Income (in k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Spending Score (1-100) vs Annual Income (in k$)')
plt.show()
# Out:
# <ipython-input-20-de45cb513299>:4: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.scatterplot(

# %%
# !pip install scikit-learn
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# Assuming 'df' is your DataFrame containing the data
# Select the features for dimensionality reduction
features = ['annual_income', 'spending_score']
X = df[features]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to reduce dimensionality
pca = PCA(n_components=2)  # Adjust n_components if needed
X_principal = pca.fit_transform(X_scaled)

# Now you can use X_principal in DBSCAN
db = DBSCAN(eps=0.0375, min_samples=50).fit(X_principal)
labels1 = db.labels_

# %%
# !pip install scikit-learn
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# Assuming 'df' is your DataFrame containing 'annual_income' and 'spending_score'
features = ['annual_income', 'spending_score']
X = df[features]

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply DBSCAN
db = DBSCAN(eps=0.3, min_samples=5)  # Adjust eps and min_samples as needed
labels = db.fit_predict(X_scaled)

# Add cluster labels to the DataFrame
df['cluster'] = labels

# Analyze the results
print(df['cluster'].value_counts())  # See the number of points in each cluster

# Visualize the clusters (if you have visualization libraries installed)
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x="annual_income", y="spending_score", hue="cluster", data=df, palette="viridis")
plt.title('DBSCAN Clustering')
plt.show()
# Out:
# ...
# cluster
#  3    88
# -1    35
#  4    30
#  5    14
#  0    12
#  6     9
#  2     7
#  1     5
# Name: count, dtype: int64

# %%
# Assuming 'labels' contains the cluster labels from DBSCAN
# and 'X_principal' has the two components (e.g., from PCA) labeled as 'P1' and 'P2'

import matplotlib.pyplot as plt

# Define the label-to-color mapping
colours = {0: 'r', 1: 'g', 2: 'b', -1: 'k'}

# Create a color vector for each data point based on cluster labels
cvec = [colours[label] for label in labels]

# Initialize the plot and legend items by plotting points for each color individually
plt.figure(figsize=(9, 9))

r = plt.scatter([], [], color='r', label='Label 0')
g = plt.scatter([], [], color='g', label='Label 1')
b = plt.scatter([], [], color='b', label='Label 2')
k = plt.scatter([], [], color='k', label='Noise (-1)')

# Plot data points using the color vector `cvec`
plt.scatter(X_principal['P1'], X_principal['P2'], c=cvec)

# Add legend and labels
plt.legend(handles=[r, g, b, k])
plt.xlabel('P1')
plt.ylabel('P2')
plt.title('DBSCAN Clustering with PCA Components')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-378f24d113a8> in <cell line: 10>()
#       8
#       9 # Create a color vector for each data point based on cluster labels
# ---> 10 cvec = [colours[label] for label in labels]
#      11
#      12 # Initialize the plot and legend items by plotting points for each color individually
#
# <ipython-input-31-378f24d113a8> in <listcomp>(.0)
#       8
#       9 # Create a color vector for each data point based on cluster labels
# ---> 10 cvec = [colours[label] for label in labels]
#      11
#      12 # Initialize the plot and legend items by plotting points for each color individually
#
# KeyError: 3
